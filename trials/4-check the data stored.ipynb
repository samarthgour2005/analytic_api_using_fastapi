# %%
import requests

# %%
path = "/api/events/7"
base_url = "http://localhost:8002" # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events/7'

# %%
response=requests.get(endpoint)
print(response.status_code)
print(response.json())
# Out:
# 404
# {'detail': 'Event not found'}
