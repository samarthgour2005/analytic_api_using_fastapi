# %%
import requests

# %%
base_url="http://localhost:8002"
detail_path = "/api/events/6/"
detail_endpoint = f"{base_url}{detail_path}"

response = requests.put(detail_endpoint, json={"page": "inline test"}) # HTTP PUT
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Wed, 17 Dec 2025 12:15:38 GMT', 'server': 'uvicorn', 'content-length': '152', 'content-type': 'application/json'}
# ok True
# {'time': '2025-12-17T08:33:29.260254Z', 'id': 6, 'page': 'inline test', 'user_agent': None, 'referrer': None, 'duration': None, 'ip_address': None, 'session_id': None} <class 'dict'> None
