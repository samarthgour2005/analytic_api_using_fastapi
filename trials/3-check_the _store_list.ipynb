# %%
import requests
from pprint import pprint
path = "/api/events"
base_url = "http://localhost:8002" # 127.0.0.1
endpoint = f"{base_url}{path}"
endpoint
# Out:
# 'http://localhost:8002/api/events'

# %%
response=requests.get(endpoint)
print(response.status_code)
pprint(response.json())
# Out:
# 200
# {'res': [{'duration': None,
#           'id': 6,
#           'ip_address': None,
#           'page': 'inline test',
#           'referrer': None,
#           'session_id': None,
#           'time': '2025-12-17T08:33:29.260254Z',
#           'user_agent': None},
#          {'duration': 0,
#           'id': 5,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:32:52.436095Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 4,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:32:49.138021Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 3,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:22:17.423986Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 2,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:22:16.436969Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 1,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:22:13.510774Z',
#           'user_agent': ''}]}

# %%
response = requests.get(endpoint, params={'duration': '15 minutes', 'pages': []})
print('ok', response.ok)
if response.ok:
    data = response.json()
    pprint(data)
# Out:
# ok True
# {'count': 6,
#  'res': [{'duration': 0,
#           'id': 1,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:22:13.510774Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 2,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:22:16.436969Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 3,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:22:17.423986Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 4,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:32:49.138021Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 5,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:32:52.436095Z',
#           'user_agent': ''},
#          {'duration': 0,
#           'id': 6,
#           'ip_address': '',
#           'page': 'ok',
#           'referrer': '',
#           'session_id': None,
#           'time': '2025-12-17T08:33:29.260254Z',
#           'user_agent': ''}]}
